# %%
# %cd /Users/r.makowiecki/PycharmProjects/MusicRecommendation/
import pandas as pd
from spotify.spotify_client import SpotifyClient
# Out:
# /Users/r.makowiecki/PycharmProjects/MusicRecommendation

# %%
artists_df = pd.read_csv("./output/every_noise_artists_output.csv")
print(artists_df.head())
print(len(artists_df))
artists_df = artists_df.drop_duplicates(subset=['spotify_artist_id'], keep=False)
print(len(artists_df))
# Out:
#                                                 name            genre  \
# 0  Canyon Vista Middle School Honors Band, percus...  school ensemble
# 1          Hunterdon Central High School Band (N.J.)  school ensemble
# 2  Elisabeth Grümmer/Elisabeth Schwarzkopf/Else S...  school ensemble
# 3          Austin O'Brien High School Grad Band 2011  school ensemble
# 4                                      The Hex Girls       iowa indie
#
#                        spotify_artist_id    r    g    b  canvas_x  canvas_y  \
# 0  spotify:artist:7nI1QVXco6ZH1Nn3vwosPo  130  110  190       767       602
# 1  spotify:artist:4nuRBJQXRWRrZB0bX33Isz  128   31  230       468       639
# 2  spotify:artist:5hPCtyzRiMZirToYjbn3HC   61  154  124        19      2292
# 3  spotify:artist:3tH9itYPqSNEfFeQ8wuQvq  211  126    0        37       166
# 4  spotify:artist:0W7NYjeoDbeF45hqtt5qmT  102  150    0       808       670
#
#    font_size
# 0        100
# 1        100
# 2        103
# 3        100
# 4        101
# ...

# %%
print(artists_df['font_size'].mean())
print(artists_df['font_size'].value_counts())
# Out:
# 103.89773597178095
# 100    68678
# 101    32802
# 102    21083
# 103    15003
# 104    11153
# 105     8393
# 106     6789
# 107     5402
# 108     4285
# 109     3531
# 110     3021
# 111     2437
# 112     2079
# 113     1748
# 114     1506
# 115     1262
# 116     1079
# 117      948
# 118      843
# 119      744
# 120      691
# 121      588
# 122      516
# 123      502
# 160      444
# 124      407
# 125      342
# 126      314
# 127      309
# 128      301
#        ...
# 130      224
# 131      188
# 132      170
# 134      155
# 133      154
# 135      133
# 136      129
# 138      107
# 140      101
# 141       97
# 137       94
# 139       89
# 143       73
# 145       71
# 142       70
# 144       58
# 146       57
# 148       57
# 151       43
# 149       42
# 147       39
# 150       38
# 152       37
# 153       33
# 154       30
# 156       29
# 159       28
# 155       24
# 157       22
# 158       21
# Name: font_size, Length: 61, dtype: int64

# %%
import time

start_time = time.time()
client = SpotifyClient()

for index, artist in artists_df[['name', 'spotify_artist_id']].iterrows():
    print(f'ARTIST NUMBER {index}    {time.ctime(int(time.time()))}')
    print(client.fetch_artist_albums(artist['spotify_artist_id']))
# Out:
# ARTIST NUMBER 0    Mon May 27 22:30:11 2019
# ([], [])
# ARTIST NUMBER 1    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 2    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 3    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 4    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 5    Mon May 27 22:30:12 2019
# (['Negative Space is a Positive Thing'], ['spotify:album:4ySF5HLRZZlPJUt6FVSsP2'])
# ARTIST NUMBER 6    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 7    Mon May 27 22:30:12 2019
# ([], [])
# ARTIST NUMBER 8    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 9    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 10    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 11    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 12    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 13    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 14    Mon May 27 22:30:13 2019
# ([], [])
# ARTIST NUMBER 15    Mon May 27 22:30:13 2019
# ([], [])
# ...

# %%
display(artists_df.head(10))
display(artists_df.head(15))

artists_df_1 = artists_df.head(n=10)
artists_df_2 = artists_df.head(n=15)

res_df = pd.concat([artists_df_1, artists_df_2])
res_df = res_df.reset_index(drop=True)
res_df = res_df.drop_duplicates(subset='spotify_artist_id', keep=False)
res_df = res_df.reset_index(drop=True)
display(res_df)
# Out:
#                                                 name            genre  \
# 0  Canyon Vista Middle School Honors Band, percus...  school ensemble
# 1          Hunterdon Central High School Band (N.J.)  school ensemble
# 2  Elisabeth Grümmer/Elisabeth Schwarzkopf/Else S...  school ensemble
# 3          Austin O'Brien High School Grad Band 2011  school ensemble
# 4                                      The Hex Girls       iowa indie
# 5                             Ramona & The Sometimes       iowa indie
# 6                                  Would You Kindly?       iowa indie
# 7                                           Stereo 3      pop chileno
# 8                                     Javiera Flores      pop chileno
# 9                            Edison High School Band  school ensemble
#
#                        spotify_artist_id    r    g    b  canvas_x  canvas_y  \
# 0  spotify:artist:7nI1QVXco6ZH1Nn3vwosPo  130  110  190       767       602
# ...

# %%
for i in range(0, 716885, 20):
    print(i)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# ...

# %%
import numpy as np

a = np.array(range(1000000))
feature_names = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',
                              'liveness', 'valence', 'tempo', 'duration_ms']
empty_feature = [None] * len(feature_names)


def fetch_audio_features():
    response = [{'danceability': 0.686, 'energy': 0.54, 'key': 7, 'loudness': -11.012, 'mode': 1, 'speechiness': 0.152, 'acousticness': 0.147, 'instrumentalness': 0, 'liveness': 0.173, 'valence': 0.501, 'tempo': 119.991, 'type': 'audio_features', 'id': '1IlcTlRl6t59ZsY4spAZus', 'uri': 'spotify:track:1IlcTlRl6t59ZsY4spAZus', 'track_href': 'https://api.spotify.com/v1/tracks/1IlcTlRl6t59ZsY4spAZus', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1IlcTlRl6t59ZsY4spAZus', 'duration_ms': 177827, 'time_signature': 4}, {'danceability': 0.453, 'energy': 0.765, 'key': 7, 'loudness': -5.818, 'mode': 1, 'speechiness': 0.0464, 'acousticness': 0.00317, 'instrumentalness': 0, 'liveness': 0.186, 'valence': 0.499, 'tempo': 144.248, 'type': 'audio_features', 'id': '0O8hrovSEOyFnHDZiMCeml', 'uri': 'spotify:track:0O8hrovSEOyFnHDZiMCeml', 'track_href': 'https://api.spotify.com/v1/tracks/0O8hrovSEOyFnHDZiMCeml', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0O8hrovSEOyFnHDZiMCeml', 'duration_ms': 125667, 'time_signature': 4}, {'danceability': 0.535, 'energy': 0.581, 'key': 2, 'loudness': -8.536, 'mode': 1, 'speechiness': 0.0496, 'acousticness': 0.343, 'instrumentalness': 0, 'liveness': 0.143, 'valence': 0.883, 'tempo': 187.547, 'type': 'audio_features', 'id': '0CzfwDRhQgRCAo35dUPZk3', 'uri': 'spotify:track:0CzfwDRhQgRCAo35dUPZk3', 'track_href': 'https://api.spotify.com/v1/tracks/0CzfwDRhQgRCAo35dUPZk3', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CzfwDRhQgRCAo35dUPZk3', 'duration_ms': 146840, 'time_signature': 4}, {'danceability': 0.35, 'energy': 0.793, 'key': 7, 'loudness': -7.077, 'mode': 1, 'speechiness': 0.0389, 'acousticness': 0.00565, 'instrumentalness': 0, 'liveness': 0.316, 'valence': 0.418, 'tempo': 182.18, 'type': 'audio_features', 'id': '0RcNjC36feCpenH0Uv7xaj', 'uri': 'spotify:track:0RcNjC36feCpenH0Uv7xaj', 'track_href': 'https://api.spotify.com/v1/tracks/0RcNjC36feCpenH0Uv7xaj', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RcNjC36feCpenH0Uv7xaj', 'duration_ms': 178160, 'time_signature': 4}, {'danceability': 0.67, 'energy': 0.549, 'key': 7, 'loudness': -8.36, 'mode': 1, 'speechiness': 0.0449, 'acousticness': 0.414, 'instrumentalness': 0, 'liveness': 0.0899, 'valence': 0.706, 'tempo': 119.64, 'type': 'audio_features', 'id': '1JHIoN0tqJQSZ3XEUSIvg4', 'uri': 'spotify:track:1JHIoN0tqJQSZ3XEUSIvg4', 'track_href': 'https://api.spotify.com/v1/tracks/1JHIoN0tqJQSZ3XEUSIvg4', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1JHIoN0tqJQSZ3XEUSIvg4', 'duration_ms': 162173, 'time_signature': 4}, {'danceability': 0.476, 'energy': 0.166, 'key': 4, 'loudness': -16.833, 'mode': 0, 'speechiness': 0.0486, 'acousticness': 0.975, 'instrumentalness': 0, 'liveness': 0.284, 'valence': 0.512, 'tempo': 80.41, 'type': 'audio_features', 'id': '60H7xXC2ZYTP874RI159FU', 'uri': 'spotify:track:60H7xXC2ZYTP874RI159FU', 'track_href': 'https://api.spotify.com/v1/tracks/60H7xXC2ZYTP874RI159FU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nDHMw01jtET2nI3KE1yLv', 'duration_ms': 190635, 'time_signature': 4}, {'danceability': 0.472, 'energy': 0.534, 'key': 5, 'loudness': -8.3, 'mode': 1, 'speechiness': 0.0262, 'acousticness': 0.00615, 'instrumentalness': 0.0326, 'liveness': 0.0837, 'valence': 0.218, 'tempo': 90.068, 'type': 'audio_features', 'id': '0NZLOaFSqLG9MO4sPldjyr', 'uri': 'spotify:track:0NZLOaFSqLG9MO4sPldjyr', 'track_href': 'https://api.spotify.com/v1/tracks/0NZLOaFSqLG9MO4sPldjyr', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NZLOaFSqLG9MO4sPldjyr', 'duration_ms': 314815, 'time_signature': 4}, {'danceability': 0.432, 'energy': 0.865, 'key': 7, 'loudness': -4.78, 'mode': 1, 'speechiness': 0.0472, 'acousticness': 0.000399, 'instrumentalness': 0.119, 'liveness': 0.223, 'valence': 0.455, 'tempo': 121.977, 'type': 'audio_features', 'id': '2jtjOrdKFMJ0TE7KugMFSb', 'uri': 'spotify:track:2jtjOrdKFMJ0TE7KugMFSb', 'track_href': 'https://api.spotify.com/v1/tracks/2jtjOrdKFMJ0TE7KugMFSb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jtjOrdKFMJ0TE7KugMFSb', 'duration_ms': 226813, 'time_signature': 4}, {'danceability': 0.266, 'energy': 0.798, 'key': 2, 'loudness': -3.681, 'mode': 1, 'speechiness': 0.0368, 'acousticness': 0.0125, 'instrumentalness': 0.31, 'liveness': 0.108, 'valence': 0.36, 'tempo': 182.078, 'type': 'audio_features', 'id': '3TMb7DevTx3Ig8CPLOt9DI', 'uri': 'spotify:track:3TMb7DevTx3Ig8CPLOt9DI', 'track_href': 'https://api.spotify.com/v1/tracks/3TMb7DevTx3Ig8CPLOt9DI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3TMb7DevTx3Ig8CPLOt9DI', 'duration_ms': 231432, 'time_signature': 4}, {'danceability': 0.385, 'energy': 0.95, 'key': 7, 'loudness': -4.463, 'mode': 1, 'speechiness': 0.0796, 'acousticness': 0.00106, 'instrumentalness': 5.49e-05, 'liveness': 0.244, 'valence': 0.515, 'tempo': 172.213, 'type': 'audio_features', 'id': '7n6hoYldTSie1YYixCURup', 'uri': 'spotify:track:7n6hoYldTSie1YYixCURup', 'track_href': 'https://api.spotify.com/v1/tracks/7n6hoYldTSie1YYixCURup', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7n6hoYldTSie1YYixCURup', 'duration_ms': 210964, 'time_signature': 4}, {'danceability': 0.263, 'energy': 0.682, 'key': 2, 'loudness': -6.158, 'mode': 1, 'speechiness': 0.039, 'acousticness': 0.00707, 'instrumentalness': 0.0364, 'liveness': 0.088, 'valence': 0.23, 'tempo': 184.05, 'type': 'audio_features', 'id': '7xYLnxSYLzbEC7lOZnsqWR', 'uri': 'spotify:track:7xYLnxSYLzbEC7lOZnsqWR', 'track_href': 'https://api.spotify.com/v1/tracks/7xYLnxSYLzbEC7lOZnsqWR', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xYLnxSYLzbEC7lOZnsqWR', 'duration_ms': 340635, 'time_signature': 4}, {'danceability': 0.456, 'energy': 0.694, 'key': 7, 'loudness': -5.977, 'mode': 1, 'speechiness': 0.0316, 'acousticness': 0.00141, 'instrumentalness': 0.0155, 'liveness': 0.33, 'valence': 0.291, 'tempo': 99.024, 'type': 'audio_features', 'id': '2xll2yzs71rHCA8z3dasc6', 'uri': 'spotify:track:2xll2yzs71rHCA8z3dasc6', 'track_href': 'https://api.spotify.com/v1/tracks/2xll2yzs71rHCA8z3dasc6', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Ws3jj4lfGKfVrC77AwJcv', 'duration_ms': 78756, 'time_signature': 4}, {'danceability': 0.551, 'energy': 0.814, 'key': 2, 'loudness': -8.25, 'mode': 1, 'speechiness': 0.0303, 'acousticness': 0.00867, 'instrumentalness': 0.515, 'liveness': 0.14, 'valence': 0.613, 'tempo': 145.023, 'type': 'audio_features', 'id': '7GHPX0JT6SV3eQN0P7XukA', 'uri': 'spotify:track:7GHPX0JT6SV3eQN0P7XukA', 'track_href': 'https://api.spotify.com/v1/tracks/7GHPX0JT6SV3eQN0P7XukA', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GHPX0JT6SV3eQN0P7XukA', 'duration_ms': 301655, 'time_signature': 4}, {'danceability': 0.517, 'energy': 0.271, 'key': 7, 'loudness': -13.506, 'mode': 1, 'speechiness': 0.0571, 'acousticness': 0.772, 'instrumentalness': 0.00743, 'liveness': 0.114, 'valence': 0.255, 'tempo': 172.035, 'type': 'audio_features', 'id': '5bwbYCe9I5RYSSPCzYHEOC', 'uri': 'spotify:track:5bwbYCe9I5RYSSPCzYHEOC', 'track_href': 'https://api.spotify.com/v1/tracks/5bwbYCe9I5RYSSPCzYHEOC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bwbYCe9I5RYSSPCzYHEOC', 'duration_ms': 129767, 'time_signature': 4}, {'danceability': 0.448, 'energy': 0.355, 'key': 11, 'loudness': -14.538, 'mode': 1, 'speechiness': 0.0603, 'acousticness': 0.861, 'instrumentalness': 0.921, 'liveness': 0.25, 'valence': 0.0347, 'tempo': 116.169, 'type': 'audio_features', 'id': '1M22YFmdZZfARzwkoJzDjp', 'uri': 'spotify:track:1M22YFmdZZfARzwkoJzDjp', 'track_href': 'https://api.spotify.com/v1/tracks/1M22YFmdZZfARzwkoJzDjp', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M22YFmdZZfARzwkoJzDjp', 'duration_ms': 68354, 'time_signature': 4}, {'danceability': 0.728, 'energy': 0.468, 'key': 11, 'loudness': -13.151, 'mode': 1, 'speechiness': 0.0323, 'acousticness': 0.0503, 'instrumentalness': 0.000102, 'liveness': 0.122, 'valence': 0.424, 'tempo': 110.052, 'type': 'audio_features', 'id': '2z1gIdkQNisTlEGk2st0up', 'uri': 'spotify:track:2z1gIdkQNisTlEGk2st0up', 'track_href': 'https://api.spotify.com/v1/tracks/2z1gIdkQNisTlEGk2st0up', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2z1gIdkQNisTlEGk2st0up', 'duration_ms': 249818, 'time_signature': 4}, {'danceability': 0.639, 'energy': 0.749, 'key': 11, 'loudness': -7.155, 'mode': 1, 'speechiness': 0.0281, 'acousticness': 0.0315, 'instrumentalness': 0.0257, 'liveness': 0.0899, 'valence': 0.883, 'tempo': 110.019, 'type': 'audio_features', 'id': '3qg2xcmZUTfcuFntcrVWpP', 'uri': 'spotify:track:3qg2xcmZUTfcuFntcrVWpP', 'track_href': 'https://api.spotify.com/v1/tracks/3qg2xcmZUTfcuFntcrVWpP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qg2xcmZUTfcuFntcrVWpP', 'duration_ms': 204000, 'time_signature': 4}, {'danceability': 0.465, 'energy': 0.45, 'key': 2, 'loudness': -7.834, 'mode': 1, 'speechiness': 0.0261, 'acousticness': 0.706, 'instrumentalness': 0.425, 'liveness': 0.113, 'valence': 0.109, 'tempo': 100.337, 'type': 'audio_features', 'id': '2PZCWHvsenz2dowI5W70ad', 'uri': 'spotify:track:2PZCWHvsenz2dowI5W70ad', 'track_href': 'https://api.spotify.com/v1/tracks/2PZCWHvsenz2dowI5W70ad', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5m1IqKK1nRPs8AIaCVmLUn', 'duration_ms': 105600, 'time_signature': 4}, {'danceability': 0.769, 'energy': 0.744, 'key': 4, 'loudness': -8.182, 'mode': 1, 'speechiness': 0.0365, 'acousticness': 0.00489, 'instrumentalness': 0.571, 'liveness': 0.0881, 'valence': 0.825, 'tempo': 115.068, 'type': 'audio_features', 'id': '4eW4i2VT9z0lBBzDVsi6Qv', 'uri': 'spotify:track:4eW4i2VT9z0lBBzDVsi6Qv', 'track_href': 'https://api.spotify.com/v1/tracks/4eW4i2VT9z0lBBzDVsi6Qv', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eW4i2VT9z0lBBzDVsi6Qv', 'duration_ms': 191478, 'time_signature': 4}, {'danceability': 0.73, 'energy': 0.676, 'key': 7, 'loudness': -9.858, 'mode': 1, 'speechiness': 0.0311, 'acousticness': 0.272, 'instrumentalness': 0.823, 'liveness': 0.113, 'valence': 0.433, 'tempo': 139.926, 'type': 'audio_features', 'id': '65p1qBjwZeEfNb9SVURVqw', 'uri': 'spotify:track:65p1qBjwZeEfNb9SVURVqw', 'track_href': 'https://api.spotify.com/v1/tracks/65p1qBjwZeEfNb9SVURVqw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/65p1qBjwZeEfNb9SVURVqw', 'duration_ms': 151286, 'time_signature': 4}, {'danceability': 0.453, 'energy': 0.839, 'key': 5, 'loudness': -8.411, 'mode': 1, 'speechiness': 0.0358, 'acousticness': 0.000232, 'instrumentalness': 0.412, 'liveness': 0.24, 'valence': 0.435, 'tempo': 150.025, 'type': 'audio_features', 'id': '61U36sT1P6581JL89SweIe', 'uri': 'spotify:track:61U36sT1P6581JL89SweIe', 'track_href': 'https://api.spotify.com/v1/tracks/61U36sT1P6581JL89SweIe', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61U36sT1P6581JL89SweIe', 'duration_ms': 187200, 'time_signature': 4}, {'danceability': 0.519, 'energy': 0.659, 'key': 4, 'loudness': -6.898, 'mode': 1, 'speechiness': 0.0248, 'acousticness': 0.000197, 'instrumentalness': 0.449, 'liveness': 0.172, 'valence': 0.213, 'tempo': 100.033, 'type': 'audio_features', 'id': '4ru9SkPwQhXLE2wYRhnZzf', 'uri': 'spotify:track:4ru9SkPwQhXLE2wYRhnZzf', 'track_href': 'https://api.spotify.com/v1/tracks/4ru9SkPwQhXLE2wYRhnZzf', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ru9SkPwQhXLE2wYRhnZzf', 'duration_ms': 170100, 'time_signature': 4}]
    features = []
    for track in response:
        if track:
            features.append([track[feature_name] for feature_name in feature_names])
        else:
            features.append(empty_feature)
    return features

# %%
# %timeit for index in range(0, len(a), 50): b = a[index:index + 50, ]; c = a[index:index + 50, ]; d= a[index:index + 50, ];e=a[index:index + 50, ];f=a[index:index + 50, ];g=a[index:index + 50, ];h = fetch_audio_features(); result=[];
# Out:
# 2.96 s ± 314 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit for index in range(0, len(a), 50): b = a[index:min(index + 50, len(a)), ];c = a[index:min(index + 50, len(a)), ];d = a[index:min(index + 50, len(a)), ];e = a[index:min(index + 50, len(a)), ];f = a[index:min(index + 50, len(a)), ];g = a[index:min(index + 50, len(a)), ];h = fetch_audio_features()
# Out:
# 3.62 s ± 928 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit a[100000:min(100020, 1232454)]
